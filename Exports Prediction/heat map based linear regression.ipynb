# %%
import pandas as pd  #importing libraries pandas,numpy,matplot
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("exports.csv")
data.head(7)
# Out:
#   code        state category  total exports   beef  pork  poultry   dairy  \
# 0   AL      Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK       Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ      Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR     Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA   California    state       16472.88  228.7  11.1    225.4  929.95
# 5   CO     Colorado    state        1851.33  261.4  66.0     14.0   71.94
# 6   CT  Connecticut    state         259.62    1.1   0.1      6.9    9.49
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# ...

# %%
drop = ['fruits fresh','fruits proc','veggies fresh','veggies proc']

# %%
data.drop(drop,inplace = True,axis = 1)
data.head(7)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-ff49891f1ec6> in <module>
# ----> 1 data.drop(drop,inplace = True,axis = 1)
#       2 data.head(7)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
import seaborn as sns #library for plotting and visualizing

# %%
sns.heatmap(data.corr(), annot=True) #creating a heat map

# %%
data
# Out:
#    code           state category  total exports   beef    pork  poultry  \
# 0    AL         Alabama    state        1390.63   34.4    10.6    481.0
# 1    AK          Alaska    state          13.31    0.2     0.1      0.0
# 2    AZ         Arizona    state        1463.17   71.3    17.9      0.0
# 3    AR        Arkansas    state        3586.02   53.2    29.4    562.9
# 4    CA      California    state       16472.88  228.7    11.1    225.4
# 5    CO        Colorado    state        1851.33  261.4    66.0     14.0
# 6    CT     Connecticut    state         259.62    1.1     0.1      6.9
# 7    DE        Delaware    state         282.19    0.4     0.6    114.7
# 8    FL         Florida    state        3764.09   42.6     0.9     56.9
# 9    GA         Georgia    state        2860.84   31.0    18.9    630.4
# 10   HI          Hawaii    state         401.84    4.0     0.7      1.3
# 11   ID           Idaho    state        2078.89  119.8     0.0      2.4
# ...

# %%
drop = ['code','state','category','beef','pork','poultry','dairy','total veggies','total fruits','wheat','cotton']

# %%
data.drop(drop,inplace = True ,axis = 1)

# %%
data
# Out:
#     total exports    corn
# 0         1390.63    34.9
# 1           13.31     0.0
# 2         1463.17     7.3
# 3         3586.02    69.5
# 4        16472.88    34.6
# 5         1851.33   183.2
# 6          259.62     0.0
# 7          282.19    26.9
# 8         3764.09     3.5
# 9         2860.84    57.8
# 10         401.84     0.0
# 11        2078.89    24.0
# 12        8709.48  2228.5
# 13        5050.23  1123.2
# 14       11273.76  2529.8
# 15        4589.01   457.3
# 16        1889.15   179.1
# 17        1914.23    91.4
# 18         278.37     0.0
# 19         692.75    54.1
# 20         248.65     0.0
# 21        3164.16   381.5
# 22        7192.33  1264.3
# 23        2170.80   110.0
# 24        3933.42   428.8
# 25        1718.00     5.4
# 26        7114.13  1735.9
# 27         139.89     0.0
# 28          73.06     0.0
# 29         500.40    10.1
# 30         751.58    11.2
# 31        1488.90   106.1
# 32        3806.05    92.2
# 33        3761.96   236.1
# ...

# %%
x = data.iloc[:,0:1].values

# %%
x
# Out:
# array([[1.390630e+03],
#        [1.331000e+01],
#        [1.463170e+03],
#        [3.586020e+03],
#        [1.647288e+04],
#        [1.851330e+03],
#        [2.596200e+02],
#        [2.821900e+02],
#        [3.764090e+03],
#        [2.860840e+03],
#        [4.018400e+02],
#        [2.078890e+03],
#        [8.709480e+03],
#        [5.050230e+03],
#        [1.127376e+04],
#        [4.589010e+03],
#        [1.889150e+03],
#        [1.914230e+03],
#        [2.783700e+02],
#        [6.927500e+02],
#        [2.486500e+02],
#        [3.164160e+03],
#        [7.192330e+03],
#        [2.170800e+03],
#        [3.933420e+03],
#        [1.718000e+03],
#        [7.114130e+03],
#        [1.398900e+02],
#        [7.306000e+01],
#        [5.004000e+02],
#        [7.515800e+02],
#        [1.488900e+03],
#        [3.806050e+03],
#        [3.761960e+03],
#        [3.979790e+03],
#        [1.646410e+03],
#        [1.794570e+03],
#        [1.969870e+03],
#        [3.159000e+01],
#        [9.299300e+02],
# ...

# %%
y = data.iloc[:,1].values
y
# Out:
# array([  34.9,    0. ,    7.3,   69.5,   34.6,  183.2,    0. ,   26.9,
#           3.5,   57.8,    0. ,   24. , 2228.5, 1123.2, 2529.8,  457.3,
#         179.1,   91.4,    0. ,   54.1,    0. ,  381.5, 1264.3,  110. ,
#         428.8,    5.4, 1735.9,    0. ,    0. ,   10.1,   11.2,  106.1,
#          92.2,  236.1,  535.1,   27.5,   11.7,  112.1,    0. ,   32.1,
#         643.6,   88.8,  167.2,    5.3,    0. ,   39.5,   29.5,    3.5,
#         460.5,    9. ])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state= 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()#created our regressor
regressor.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
x.shape
# Out:
# (50, 1)

# %%
y.shape
# Out:
# (50,)

# %%
ypred = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,ypred)
# Out:
# -0.0009300258166491382
